# %%
from matplotlib import pyplot
import pandas as pd
pyplot.rcParams["figure.figsize"] = (20,5)

# %%
# FILE_PATH = "./build/juce_fft_equalizer_artefacts/Debug/last_band_data.csv"
FILE_PATH = "./build/juce_fft_equalizer_artefacts/Debug/fft_log_0.csv"

# %%
table = pd.read_csv(FILE_PATH, header=0, comment='#')
show_table = table[0:1000]
pyplot.plot(show_table.harmonic, show_table.magnitude)
open(FILE_PATH, 'r').readlines()[0][1:-1]
# Out:
# 'sample_rate=44100, fft_size=2048'
